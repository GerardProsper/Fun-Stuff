# %%
# I created this to look at a few universities I had compiled to study in Ireland
# I take data in from an excel and cleaned it to be displayed in a table form using pandas
# I analyzed the cost and decided on which uni's to apply to

# %%
import pandas as pd

# %%
df = pd.read_excel(r'C:\Users\Lenovo Pc\Desktop\GP\Masters 2021\Ireland\Masters Ireland.xlsx', header=0, 
                   index_col=None, sheet_name='Ireland Uni')

# %%
df
# Out:
#     Unnamed: 0                             Unnamed: 1   Unnamed: 2  \
# 0          NaN                             University     Location
# 1          NaN    Letterkenny Institute of Technology  Letterkenny
# 2          NaN                           Waterford IT    Waterford
# 3          NaN                              IT Carlow       Carlow
# 4          NaN           Cork Institute of Technology         Cork
# 5          NaN        Athlone Institute of Technology      Athlone
# 6          NaN                             Dundalk IT      Dundalk
# 7          NaN                 University of Limerick     Limerick
# 8          NaN                              TU Dublin          NaN
# 9          NaN                 University of Limerick     Limerick
# 10         NaN                    Maynooth University          NaN
# 11         NaN                    Maynooth University          NaN
# 12         NaN                 Dublin City University          NaN
# ...

# %%
df.drop(columns=['Unnamed: 0','Unnamed: 5','Unnamed: 6','Unnamed: 7','Unnamed: 8','Unnamed: 11', 'Unnamed: 12'], inplace=True)

# %%
df
# Out:
#                                Unnamed: 1   Unnamed: 2          Unnamed: 3  \
# 0                              University     Location  Distance to Dublin
# 1     Letterkenny Institute of Technology  Letterkenny               238km
# 2                            Waterford IT    Waterford               166km
# 3                               IT Carlow       Carlow                92km
# 4            Cork Institute of Technology         Cork               253km
# 5         Athlone Institute of Technology      Athlone               120km
# 6                              Dundalk IT      Dundalk                81km
# 7                  University of Limerick     Limerick               198km
# 8                               TU Dublin          NaN                 NaN
# 9                  University of Limerick     Limerick               198km
# 10                    Maynooth University          NaN                 NaN
# ...

# %%
df.columns = df.iloc[0]

# %%
df.drop([0],inplace=True)

# %%
df
# Out:
# 0                              University     Location Distance to Dublin  \
# 1     Letterkenny Institute of Technology  Letterkenny              238km
# 2                            Waterford IT    Waterford              166km
# 3                               IT Carlow       Carlow               92km
# 4            Cork Institute of Technology         Cork              253km
# 5         Athlone Institute of Technology      Athlone              120km
# 6                              Dundalk IT      Dundalk               81km
# 7                  University of Limerick     Limerick              198km
# 8                               TU Dublin          NaN                NaN
# 9                  University of Limerick     Limerick              198km
# 10                    Maynooth University          NaN                NaN
# 11                    Maynooth University          NaN                NaN
# 12                 Dublin City University          NaN                NaN
# ...

# %%
df['Location'].fillna('Dublin', inplace=True)

# %%
df
# Out:
# 0                              University     Location Distance to Dublin  \
# 1     Letterkenny Institute of Technology  Letterkenny              238km
# 2                            Waterford IT    Waterford              166km
# 3                               IT Carlow       Carlow               92km
# 4            Cork Institute of Technology         Cork              253km
# 5         Athlone Institute of Technology      Athlone              120km
# 6                              Dundalk IT      Dundalk               81km
# 7                  University of Limerick     Limerick              198km
# 8                               TU Dublin       Dublin                NaN
# 9                  University of Limerick     Limerick              198km
# 10                    Maynooth University       Dublin                NaN
# 11                    Maynooth University       Dublin                NaN
# 12                 Dublin City University       Dublin                NaN
# ...

# %%
df['Distance to Dublin'].fillna(0, inplace=True)

# %%
df
# Out:
# 0                              University     Location Distance to Dublin  \
# 1     Letterkenny Institute of Technology  Letterkenny              238km
# 2                            Waterford IT    Waterford              166km
# 3                               IT Carlow       Carlow               92km
# 4            Cork Institute of Technology         Cork              253km
# 5         Athlone Institute of Technology      Athlone              120km
# 6                              Dundalk IT      Dundalk               81km
# 7                  University of Limerick     Limerick              198km
# 8                               TU Dublin       Dublin                  0
# 9                  University of Limerick     Limerick              198km
# 10                    Maynooth University       Dublin                  0
# 11                    Maynooth University       Dublin                  0
# 12                 Dublin City University       Dublin                  0
# ...

# %%
df.rename(columns={'Distance to Dublin':'Distance to Dublin (km)'},inplace=True)

# %%
df
# Out:
# 0                              University     Location  \
# 1     Letterkenny Institute of Technology  Letterkenny
# 2                            Waterford IT    Waterford
# 3                               IT Carlow       Carlow
# 4            Cork Institute of Technology         Cork
# 5         Athlone Institute of Technology      Athlone
# 6                              Dundalk IT      Dundalk
# 7                  University of Limerick     Limerick
# 8                               TU Dublin       Dublin
# 9                  University of Limerick     Limerick
# 10                    Maynooth University       Dublin
# 11                    Maynooth University       Dublin
# 12                 Dublin City University       Dublin
# 13  National University of Ireland Galway       Galway
# 14                University College Cork         Cork
# 15              University College Dublin       Dublin
# 16              University College Dublin       Dublin
# ...

# %%
df['Distance to Dublin (km)'] = df['Distance to Dublin (km)'].str.rstrip('km')

# Series.str.strip - Remove leading and trailing characters in Series/Index.
# Series.str.lstrip - Remove leading characters in Series/Index.
# Series.str.rstrip - Remove trailing characters in Series/Index.

# %%
df
# Out:
# 0                              University     Location  \
# 1     Letterkenny Institute of Technology  Letterkenny
# 2                            Waterford IT    Waterford
# 3                               IT Carlow       Carlow
# 4            Cork Institute of Technology         Cork
# 5         Athlone Institute of Technology      Athlone
# 6                              Dundalk IT      Dundalk
# 7                  University of Limerick     Limerick
# 8                               TU Dublin       Dublin
# 9                  University of Limerick     Limerick
# 10                    Maynooth University       Dublin
# 11                    Maynooth University       Dublin
# 12                 Dublin City University       Dublin
# 13  National University of Ireland Galway       Galway
# 14                University College Cork         Cork
# 15              University College Dublin       Dublin
# 16              University College Dublin       Dublin
# ...

# %%
df['Distance to Dublin (km)'].fillna(0, inplace=True)

# %%
df
# Out:
# 0                              University     Location  \
# 1     Letterkenny Institute of Technology  Letterkenny
# 2                            Waterford IT    Waterford
# 3                               IT Carlow       Carlow
# 4            Cork Institute of Technology         Cork
# 5         Athlone Institute of Technology      Athlone
# 6                              Dundalk IT      Dundalk
# 7                  University of Limerick     Limerick
# 8                               TU Dublin       Dublin
# 9                  University of Limerick     Limerick
# 10                    Maynooth University       Dublin
# 11                    Maynooth University       Dublin
# 12                 Dublin City University       Dublin
# 13  National University of Ireland Galway       Galway
# 14                University College Cork         Cork
# 15              University College Dublin       Dublin
# 16              University College Dublin       Dublin
# ...

# %%
df.rename(columns={'Total Fees':'Total Fees (EU)'},inplace=True)

# %%
df
# Out:
# 0                              University     Location  \
# 1     Letterkenny Institute of Technology  Letterkenny
# 2                            Waterford IT    Waterford
# 3                               IT Carlow       Carlow
# 4            Cork Institute of Technology         Cork
# 5         Athlone Institute of Technology      Athlone
# 6                              Dundalk IT      Dundalk
# 7                  University of Limerick     Limerick
# 8                               TU Dublin       Dublin
# 9                  University of Limerick     Limerick
# 10                    Maynooth University       Dublin
# 11                    Maynooth University       Dublin
# 12                 Dublin City University       Dublin
# 13  National University of Ireland Galway       Galway
# 14                University College Cork         Cork
# 15              University College Dublin       Dublin
# 16              University College Dublin       Dublin
# ...

# %%
print(df.columns.tolist())
# Out:
# ['University', 'Location', 'Distance to Dublin (km)', 'Course', 'Total Fees (EU)', 'Total Fees(USD)']

# %%
df.drop(columns=['USD '], inplace=True)

# %%
df['Course'].value_counts()
# Out:
# Business Analytics                                5
# Artificial Intelligence                           1
# Sustainable Electrical Energy Systems             1
# Computer Science (Data Science)                   1
# Business Information & Analytics System           1
# Computing - Data Analytics                        1
# Data Science                                      1
# Sustainable Energy Engineering                    1
# Data Science and Analytics                        1
# Big Data Analytics and Artificial Intelligence    1
# CS - AI                                           1
# Artificial Intelligence & Machine Learning        1
# Software Design With Artificial Intelligence      1
# Data & Computational Science                      1
# CS - Data Analytics                               1
# Data Analytics                                    1
# CS - Intelligent Systems                          1
# Name: Course, dtype: int64

# %%
df
# Out:
# 0                              University     Location  \
# 1     Letterkenny Institute of Technology  Letterkenny
# 2                            Waterford IT    Waterford
# 3                               IT Carlow       Carlow
# 4            Cork Institute of Technology         Cork
# 5         Athlone Institute of Technology      Athlone
# 6                              Dundalk IT      Dundalk
# 7                  University of Limerick     Limerick
# 8                               TU Dublin       Dublin
# 9                  University of Limerick     Limerick
# 10                    Maynooth University       Dublin
# 11                    Maynooth University       Dublin
# 12                 Dublin City University       Dublin
# 13  National University of Ireland Galway       Galway
# 14                University College Cork         Cork
# 15              University College Dublin       Dublin
# 16              University College Dublin       Dublin
# ...

# %%
df['Total Fees(USD)']=df['Total Fees (EU)']*1.25

# %%
df
# Out:
# 0                              University     Location  \
# 1     Letterkenny Institute of Technology  Letterkenny
# 2                            Waterford IT    Waterford
# 3                               IT Carlow       Carlow
# 4            Cork Institute of Technology         Cork
# 5         Athlone Institute of Technology      Athlone
# 6                              Dundalk IT      Dundalk
# 7                  University of Limerick     Limerick
# 8                               TU Dublin       Dublin
# 9                  University of Limerick     Limerick
# 10                    Maynooth University       Dublin
# 11                    Maynooth University       Dublin
# 12                 Dublin City University       Dublin
# 13  National University of Ireland Galway       Galway
# 14                University College Cork         Cork
# 15              University College Dublin       Dublin
# 16              University College Dublin       Dublin
# ...

# %%
df['Total Fees(USD)'].mean()
# Out:
# 24308.928571428572

# %%
df.loc[df['Total Fees(USD)'] < df['Total Fees(USD)'].mean()]
# Out:
# 0                            University     Location Distance to Dublin (km)  \
# 1   Letterkenny Institute of Technology  Letterkenny                     238
# 2                          Waterford IT    Waterford                     166
# 3                             IT Carlow       Carlow                      92
# 4          Cork Institute of Technology         Cork                     253
# 5       Athlone Institute of Technology      Athlone                     120
# 6                            Dundalk IT      Dundalk                      81
# 7                University of Limerick     Limerick                     198
# 8                             TU Dublin       Dublin                       0
# 9                University of Limerick     Limerick                     198
# 10                  Maynooth University       Dublin                       0
# 11                  Maynooth University       Dublin                       0
#
# ...

# %%
df.loc[df['Total Fees(USD)'] > df['Total Fees(USD)'].mean()]
# Out:
# 0                              University Location Distance to Dublin (km)  \
# 12                 Dublin City University   Dublin                       0
# 13  National University of Ireland Galway   Galway                     208
# 14                University College Cork     Cork                     253
# 15              University College Dublin   Dublin                       0
# 16              University College Dublin   Dublin                       0
# 17                 Trinity College Dublin   Dublin                       0
# 18  National University of Ireland Galway   Galway                     208
# 19  National University of Ireland Galway   Galway                     208
# 20                              TU Dublin   Dublin                       0
# 21                 Trinity College Dublin   Dublin                       0
#
# 0                                    Course Total Fees (EU) Total Fees(USD)
# ...
